# %%
import scanpy as sc
import pandas as pd
# Out:
# /home/sban/miniconda3/envs/organoid/lib/python3.6/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
ad = sc.read("PrimaryCell_UCSC/primarymatrix_nonorm.txt.gz",cache=True, dtype='float16')

# %%
ad.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b55e06f4707c> in <module>
# ----> 1 ad.head()
#
# NameError: name 'ad' is not defined

# %%
with open('Organoid_NCBI/GSE132672_allorganoids_withnew_matrix.txt') as f:
    counter = 0
    for line in f:
        print(line)
        counter += 1
        if counter == 1:
            break
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
